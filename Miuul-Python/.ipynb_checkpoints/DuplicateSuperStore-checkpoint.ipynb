# %%
import pandas as pd

# %%
df = pd.read_csv("archive/Results.csv")

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
duplicate_product_names = (
    df.groupby('Product_Name')
    .filter(lambda x: x['Product_ID'].nunique() > 1)['Product_Name']
    .unique()
)
print(duplicate_product_names)
# Out:
# ['Easy-staple paper' 'Staples' 'Staple envelope'
#  'Staple-based wall hangings' 'Storex Dura Pro Binders'
#  'Avery Non-Stick Binders' 'Eldon Wave Desk Accessories' 'Staple remover'
#  'Staple holder' 'Staple magnet' '#10- 4 1/8" x 9 1/2" Recycled Envelopes'
#  'Staples in misc. colors' 'KI Adjustable-Height Table'
#  'Prang Drawing Pencil Set'
#  'Peel & Seel Recycled Catalog Envelopes, Brown' 'Okidata C610n Printer']

# %%
product_names = duplicate_product_names
product_names
# Out:
# array(['Easy-staple paper', 'Staples', 'Staple envelope',
#        'Staple-based wall hangings', 'Storex Dura Pro Binders',
#        'Avery Non-Stick Binders', 'Eldon Wave Desk Accessories',
#        'Staple remover', 'Staple holder', 'Staple magnet',
#        '#10- 4 1/8" x 9 1/2" Recycled Envelopes',
#        'Staples in misc. colors', 'KI Adjustable-Height Table',
#        'Prang Drawing Pencil Set',
#        'Peel & Seel Recycled Catalog Envelopes, Brown',
#        'Okidata C610n Printer'], dtype=object)

# %%
df1 = pd.read_excel("archive/Book1.xlsx", sheet_name="Sheet2")

# %%
df1.head(30)
# Out:
#    #10- 4 1/8" x 9 1/2" Recycled Envelopes Avery Non-Stick Binders  \
# 0                          OFF-EN-10000461         OFF-BI-10004140
# 1                          OFF-EN-10000781         OFF-BI-10000829
# 2                                      NaN                     NaN
# 3                                      NaN                     NaN
# 4                                      NaN                     NaN
# 5                                      NaN                     NaN
# 6                                      NaN                     NaN
# 7                                      NaN                     NaN
# 8                                      NaN                     NaN
# 9                                      NaN                     NaN
# 10                                     NaN                     NaN
#
#    Easy-staple paper Eldon Wave Desk Accessories KI Adjustable-Height Table  \
# 0    OFF-PA-10000474             FUR-FU-10000023            FUR-TA-10001039
# ...

# %%
df1.columns
# Out:
# Index(['#10- 4 1/8" x 9 1/2" Recycled Envelopes', 'Avery Non-Stick Binders',
#        'Easy-staple paper', 'Eldon Wave Desk Accessories',
#        'KI Adjustable-Height Table', 'Okidata C610n Printer',
#        'Peel & Seel Recycled Catalog Envelopes, Brown',
#        'Prang Drawing Pencil Set', 'Staple envelope', 'Staple holder',
#        'Staple magnet', 'Staple remover', 'Staple-based wall hangings',
#        'Staples', 'Staples in misc. colors', 'Storex Dura Pro Binders'],
#       dtype='object')

# %%
df1.values
# Out:
# array([['OFF-EN-10000461', 'OFF-BI-10004140', 'OFF-PA-10000474',
#         'FUR-FU-10000023', 'FUR-TA-10001039', 'TEC-MA-10003230',
#         'OFF-EN-10003448', 'OFF-AR-10003251', 'OFF-EN-10003286',
#         'OFF-AP-10004249', 'OFF-ST-10002562', 'OFF-SU-10000946',
#         'FUR-FU-10004351', 'OFF-FA-10002780', 'OFF-AR-10004062',
#         'OFF-BI-10004364'],
#        ['OFF-EN-10000781', 'OFF-BI-10000829', 'OFF-PA-10000349',
#         'FUR-FU-10003981', 'FUR-TA-10004086', 'TEC-MA-10001856',
#         'OFF-EN-10002592', 'OFF-AR-10002766', 'OFF-EN-10001990',
#         'OFF-AP-10002222', 'OFF-ST-10003221', 'OFF-SU-10001225',
#         'FUR-FU-10001940', 'OFF-FA-10002815', 'OFF-AR-10003631',
#         'OFF-BI-10001922'],
#        ['OFF-EN-10000461]', nan, 'OFF-PA-10001685', nan, nan, nan, nan,
#         nan, 'OFF-EN-10004773', 'OFF-AP-10001366', nan,
#         'OFF-SU-10001935', nan, 'OFF-FA-10002975', 'OFF-AR-10003087',
#         nan],
# ...

# %%
# Out:
# array(['OFF-EN-10000461', 'OFF-EN-10000781'], dtype=object)

# %%
df3 = pd.DataFrame()

for col in range(len(df1.columns)):
    filtered_df = df[df["Product_ID"].isin(df1[df1.columns[col]].dropna().values)]
    df3 = pd.concat([df3, filtered_df], ignore_index=True) 
    print(filtered_df[["Product_Name", "Product_ID"]])
# Out:
#                                  Product_Name       Product_ID
# 985   #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
# 1989  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000781
# 2447  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
# 2948  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
# 4378  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
# 4992  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
# 5216  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
# 5688  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000781
# 6301  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
# 7720  #10- 4 1/8" x 9 1/2" Recycled Envelopes  OFF-EN-10000461
#                  Product_Name       Product_ID
# 337   Avery Non-Stick Binders  OFF-BI-10004140
# 1102  Avery Non-Stick Binders  OFF-BI-10004140
# 1849  Avery Non-Stick Binders  OFF-BI-10004140
# 2167  Avery Non-Stick Binders  OFF-BI-10004140
# ...

# %%
df3 = df3[["Product_Name", "Product_ID"]]
df3.to_csv("son1.csv")

# %%
df2 = df[df["Product_ID"].isin(df1.values)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 df2 = df[df["Product_ID"].isin(df1.values)]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:5559, in Series.isin(self, values)
#    5486 def isin(self, values) -> Series:
#    5487     """
#    5488     Whether elements in Series are contained in `values`.
#    5489
#    (...)
#    5557     dtype: bool
#    5558     """
# -> 5559     result = algorithms.isin(self._values, values)
#    5560     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5561         self, method="isin"
#    5562     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:545, in isin(comps, values)
#     542     comps_array = comps_array.astype(common, copy=False)
#     543     f = htable.ismember
# --> 545 return f(comps_array, values)
#
# ...

# %%
column_list = []
for col in df1.columns:
    column_list.append(df1[col].dropna().tolist())
    a = df1[col].dropna().tolist()
    df2 = df[df["Product_ID"].isin(a)]
    df2.head()

# %%
print(column_list)
# Out:
# [['OFF-EN-10000461', 'OFF-EN-10000781', 'OFF-EN-10000461]'], ['OFF-BI-10004140', 'OFF-BI-10000829'], ['OFF-PA-10000474', 'OFF-PA-10000349', 'OFF-PA-10001685', 'OFF-PA-10003127', 'OFF-PA-10000249', 'OFF-PA-10000565', 'OFF-PA-10004947', 'OFF-PA-10002764'], ['FUR-FU-10000023', 'FUR-FU-10003981'], ['FUR-TA-10001039', 'FUR-TA-10004086'], ['TEC-MA-10003230', 'TEC-MA-10001856'], ['OFF-EN-10003448', 'OFF-EN-10002592'], ['OFF-AR-10003251', 'OFF-AR-10002766'], ['OFF-EN-10003286', 'OFF-EN-10001990', 'OFF-EN-10004773', 'OFF-EN-10002621', 'OFF-EN-10001539', 'OFF-EN-10003134', 'OFF-EN-10001099', 'OFF-EN-10001415', 'OFF-EN-10001028', ' OFF-EN-10003134', ' OFF-EN-10001990'], ['OFF-AP-10004249', 'OFF-AP-10002222', 'OFF-AP-10001366'], ['OFF-ST-10002562', 'OFF-ST-10003221'], ['OFF-SU-10000946', 'OFF-SU-10001225', 'OFF-SU-10001935'], ['FUR-FU-10004351', 'FUR-FU-10001940'], ['OFF-FA-10002780', 'OFF-FA-10002815', 'OFF-FA-10002975', 'OFF-FA-10003485', 'OFF-FA-10000735', 'OFF-FA-10003021', 'OFF-FA-10003495'
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Row_ID, Order_ID, Order_Date, Ship_Date, Ship_Mode, Customer_ID, Customer_Name, Segment, Country, City, State, Postal_Code, Region, Product_ID, Category, Sub_Category, Product_Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df1 = pd.read_excel("archive/Book1.xlsx", sheet_name="Results")

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
df1["Product_ID"].drop_duplicates().count()
# Out:
# 1817

# %%
df1["Product_Name"].drop_duplicates().count()
# Out:
# 1850

# %%
df3 = df1.groupby("Product_ID").agg({"Product_Name":"count"})
df3.head()
type(df3["Product_Name"])
# Out:
# pandas.core.series.Series

# %%
df3[df3["Product_Name"] > 1].to_csv("ind.csv")

# %%
grouped = df1.groupby("Product_ID")["Product_Name"]

# %%
print(grouped.apply(list))
# Out:
# Product_ID
# FUR-BO-10000112    [Bush Birmingham Collection Bookcase, Dark Che...
# FUR-BO-10000330    [Sauder Camden County Barrister Bookcase, Plan...
# FUR-BO-10000362    [Sauder Inglewood Library Bookcases, Sauder In...
# FUR-BO-10000468    [O'Sullivan 2-Shelf Heavy-Duty Bookcases, O'Su...
# FUR-BO-10000711    [Hon Metal Bookcases, Gray, Hon Metal Bookcase...
#                                          ...
# TEC-PH-10004912    [Cisco SPA112 2 Port Phone Adapter, Cisco SPA1...
# TEC-PH-10004922    [RCA Visys Integrated PBX 8-Line Router, RCA V...
# TEC-PH-10004924    [SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" ...
# TEC-PH-10004959    [Classic Ivory Antique�Telephone�ZL1810, Class...
# TEC-PH-10004977    [GE 30524EE4, GE 30524EE4, GE 30524EE4, GE 305...
# Name: Product_Name, Length: 1817, dtype: object

# %%
df1
# Out:
# array([[1, 'CA-2016-152156', Timestamp('2016-11-08 00:00:00'), ..., 2, 0,
#         419136],
#        [2, 'CA-2016-152156', Timestamp('2016-11-08 00:00:00'), ..., 3, 0,
#         219582],
#        [3, 'CA-2016-138688', Timestamp('2016-06-12 00:00:00'), ..., 2, 0,
#         68714],
#        ...,
#        [9992, 'CA-2017-121258', Timestamp('2017-02-26 00:00:00'), ..., 2,
#         2, 193932],
#        [9993, 'CA-2017-121258', Timestamp('2017-02-26 00:00:00'), ..., 4,
#         0, 1332],
#        [9994, 'CA-2017-119914', Timestamp('2017-05-04 00:00:00'), ..., 2,
#         0, 72948]], dtype=object)

# %%
grouped.apply(list).to_csv("groupProductID.csv")

# %%
df8 = pd.read_excel("archive/Book1.xlsx", sheet_name="Sheet10")
df8.head()
# Out:
#              Name1
# 0  FUR-BO-10002213
# 1  FUR-CH-10001146
# 2  FUR-FU-10001473
# 3  FUR-FU-10004017
# 4  FUR-FU-10004091

# %%
isinProdcut = df8["Name1"]
isinProdcut
# Out:
# 0     FUR-BO-10002213
# 1     FUR-CH-10001146
# 2     FUR-FU-10001473
# 3     FUR-FU-10004017
# 4     FUR-FU-10004091
# 5     FUR-FU-10004270
# 6     FUR-FU-10004848
# 7     FUR-FU-10004864
# 8     OFF-AP-10000576
# 9     OFF-AR-10001149
# 10    OFF-BI-10002026
# 11    OFF-BI-10004632
# 12    OFF-BI-10004654
# 13    OFF-FA-10002780
# 14    OFF-PA-10000357
# 15    OFF-PA-10000477
# 16    OFF-PA-10000659
# 17    OFF-PA-10001166
# 18    OFF-PA-10001970
# 19    OFF-PA-10002195
# 20    OFF-PA-10002377
# 21    OFF-PA-10003022
# 22    OFF-ST-10001228
# 23    OFF-ST-10004950
# 24    TEC-AC-10002049
# 25    TEC-AC-10002550
# 26    TEC-AC-10003832
# 27    TEC-MA-10001148
# 28    TEC-PH-10001530
# 29    TEC-PH-10001795
# 30    TEC-PH-10002200
# 31    TEC-PH-10002310
# 32    TEC-PH-10004531
# Name: Name1, dtype: object

# %%
df1.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
df9 = df1[df1["Product_ID"].isin(df8["Name1"].values)]

# %%
df9 = df9[~df9.duplicated(subset=['Product_ID', 'Product_Name'], keep='first')]

# %%
df9.describe
# Out:
# <bound method NDFrame.describe of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 29        30  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 66        67  US-2015-164175 2015-04-30 2015-05-05  Standard Class
# 70        71  CA-2016-106075 2016-09-18 2016-09-23  Standard Class
# 128      129  US-2016-125969 2016-11-06 2016-11-10    Second Class
# 131      132  US-2017-164147 2017-02-02 2017-02-05     First Class
# ...      ...             ...        ...        ...             ...
# 4792    4792  CA-2015-104346 2015-12-11 2015-12-16  Standard Class
# 5317    5318  US-2017-162558 2017-10-02 2017-10-05     First Class
# 5407    5408  CA-2017-108854 2017-12-08 2017-12-14  Standard Class
# 5513    5514  CA-2015-103177 2015-05-30 2015-06-01     First Class
# 5951    5952  CA-2017-161046 2017-03-05 2017-03-05        Same Day
#
#      Customer_ID      Customer_Name      Segment        Country  \
# ...

# %%
df9[["Product_ID","Product_Name"]].to_csv("isin.csv")

# %%
col = pd.read_excel("archive/Book1.xlsx", sheet_name="Sheet11")
col.head()
# Out:
#         Product_ID                                       Product_Name
# 0  FUR-AA-10002214              DMI Eclipse Executive Suite Bookcases
# 1  FUR-AA-10001147        Global Value Mid-Back Manager's Chair, Gray
# 2  FUR-AA-10001474                            DAX Wood Document Frame
# 3  FUR-AA-10004018  Tenex Contemporary Contur Chairmats for Low an...
# 4  FUR-AA-10004092  Howard Miller 13" Diameter Goldtone Round Wall...

# %%
for i in range(0, len(col.index)):
    product_name = col["Product_Name"].iloc[i]
    mask = df["Product_Name"] == product_name
    if mask.any():
        df.loc[mask, 'Product_ID'] = col["Product_ID"].iloc[i]

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
df.to_csv("son1.1.csv")

# %%
son = pd.read_excel("archive/Book1.xlsx", sheet_name="sonn")
son.head()
# Out:
#    Column1  Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0        0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1        1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
#
#   Customer_ID    Customer_Name    Segment        Country  ... Postal_Code  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...       42420
# 1    CG-12520      Claire Gute   Consumer  United States  ...       42420
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...       90036
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...       33311
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...       33311
#
#   Region       Product_ID         Category Sub_Category  \
# ...

# %%
son.drop("Column1", axis=1, inplace=True)

# %%
son.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
son.to_csv("SuperStore1.2.csv")

# %%
son["Product_ID"].drop_duplicates().count()
# Out:
# 1885

# %%
son["Product_Name"].drop_duplicates().count()
# Out:
# 1850

# %%
df = pd.read_excel("archive/Book1.xlsx", sheet_name="sonn")

# %%
df.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
df1 = pd.read_excel("archive/Book1.xlsx", sheet_name="Sheet5")

# %%
df1.head()
# Out:
#               Porduct_Name       Product_ID
# 0          Staple envelope  OFF-AA-10001990
# 1        Easy-staple paper  OFF-AA-10000249
# 2  Staples in misc. colors  OFF-AA-10001166
# 3            Staple holder  OFF-AA-10004249
# 4           Staple remover  OFF-AA-10001225

# %%
for i in range(0, len(df1.index)):
    product_name = df1["Porduct_Name"].iloc[i]
    mask = df["Product_Name"] == product_name
    if mask.any():
        df.loc[mask, 'Product_ID'] = col["Product_ID"].iloc[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Product_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[302], line 2
#       1 for i in range(0, len(df1.index)):
# ...
