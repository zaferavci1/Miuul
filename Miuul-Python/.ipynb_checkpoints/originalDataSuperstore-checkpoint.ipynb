# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_ = pd.read_csv("archive/superStoreDB.csv")
df = df_.copy()

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
df.tail()
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer_ID     Customer_Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
result = df.groupby(["Product_ID"]).agg({"Quantity":"sum"}).rename(columns={"Quantity": "quantity_sum"}).sort_values(by="quantity_sum", ascending=False).head().reset_index()
max_product_ID = result.iloc[0]['Product_ID']
[val for val in df[df["Product_ID"] == max_product_ID]["Order_ID"]]
select_order_ID = [val for val in df[df["Product_ID"] == max_product_ID]["Order_ID"].values]

# %%
result
# Out:
#         Product_ID  quantity_sum
# 0  TEC-AC-10003832            75
# 1  OFF-PA-10001970            70
# 2  OFF-BI-10001524            67
# 3  FUR-CH-10002647            64
# 4  OFF-BI-10002026            64

# %%
[val for val in df[df["Product_ID"] == "OFF-PA-10001970"]["Order_ID"]]

# %%
[val for val in df[df["Product_ID"] == "OFF-PA-10001970"]["Order_ID"]]
# Out:
# ['CA-2016-129714',
#  'CA-2016-129714',
#  'CA-2017-117457',
#  'CA-2016-147375',
#  'CA-2016-152814',
#  'CA-2015-142755',
#  'CA-2017-117212',
#  'US-2017-129777',
#  'CA-2015-142377',
#  'CA-2016-119963',
#  'CA-2015-105158',
#  'CA-2014-133305',
#  'CA-2017-102197',
#  'CA-2017-124744',
#  'CA-2015-156013',
#  'CA-2015-121776',
#  'CA-2017-156776',
#  'US-2017-127292',
#  'CA-2016-113607']

# %%
[col for col in select_order_ID]
# Out:
# ['US-2017-100930',
#  'CA-2016-145625',
#  'US-2016-139486',
#  'CA-2017-106103',
#  'CA-2017-130351',
#  'US-2017-132444',
#  'CA-2016-105963',
#  'CA-2016-111794',
#  'CA-2016-134887',
#  'CA-2014-127558',
#  'CA-2016-133795',
#  'US-2014-159618',
#  'CA-2017-140872',
#  'CA-2016-108224',
#  'CA-2017-162015',
#  'CA-2017-116988',
#  'US-2015-115343',
#  'CA-2016-129280']

# %%
df1 = df[df["Order_ID"].isin(select_order_ID)] #en çok satılan ürünün order_id leri

# %%
df1.head(10)
# Out:
#      Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 231     232  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 232     233  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 233     234  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 234     235  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 235     236  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 251     251  CA-2016-145625  9/11/2016  9/17/2016  Standard Class    KC-16540
# 252     252  CA-2016-145625  9/11/2016  9/17/2016  Standard Class    KC-16540
# 524     524  US-2016-139486  5/21/2016  5/23/2016     First Class    LH-17155
# 525     525  US-2016-139486  5/21/2016  5/23/2016     First Class    LH-17155
# 644     644  CA-2017-106103  6/10/2017  6/15/2017  Standard Class    SC-20305
#
#           Customer_Name      Segment        Country             City  ...  \
# ...

# %%
df1[df1["Order_ID"] == 'US-2017-100930']
# Out:
#      Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 231     232  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 232     233  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 233     234  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 234     235  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
# 235     236  US-2017-100930   4/7/2017  4/12/2017  Standard Class    CS-12400
#
#           Customer_Name      Segment        Country   City  ... Postal_Code  \
# 231  Christopher Schild  Home Office  United States  Tampa  ...       33614
# 232  Christopher Schild  Home Office  United States  Tampa  ...       33614
# 233  Christopher Schild  Home Office  United States  Tampa  ...       33614
# 234  Christopher Schild  Home Office  United States  Tampa  ...       33614
# 235  Christopher Schild  Home Office  United States  Tampa  ...       33614
#
# ...

# %%
result1 = df1.groupby("Product_ID").agg({"Quantity":"sum"}).rename(columns={"Quantity": "sum"}).sort_values(by="sum", ascending=False)

# %%
result1
# Out:
#                  sum
# Product_ID
# TEC-AC-10003832   75
# OFF-PA-10004100    7
# OFF-AP-10002287    7
# OFF-ST-10003442    6
# OFF-SU-10000432    6
# TEC-PH-10000441    5
# OFF-PA-10002137    5
# OFF-AP-10003040    5
# OFF-ST-10002554    5
# OFF-SU-10000898    5
# FUR-FU-10003731    4
# TEC-PH-10003555    3
# OFF-BI-10002432    3
# OFF-PA-10003848    3
# OFF-PA-10000809    3
# OFF-ST-10000563    3
# TEC-AC-10002637    3
# OFF-AP-10004532    3
# FUR-TA-10003473    3
# TEC-MA-10003589    3
# FUR-FU-10004017    3
# FUR-FU-10002505    3
# FUR-FU-10001290    3
# TEC-AC-10001465    2
# OFF-SU-10002537    2
# TEC-AC-10002942    2
# FUR-BO-10002824    2
# OFF-LA-10000081    2
# OFF-FA-10000611    2
# OFF-BI-10001679    2
# OFF-BI-10001116    2
# OFF-AP-10003622    2
# FUR-TA-10001705    2
# FUR-FU-10001876    2
# OFF-PA-10004569    1
# FUR-BO-10004467    1
# OFF-AR-10003183    1
# OFF-PA-10000474    1

# %%
result1 = df1.groupby("Product_ID").agg({"Quantity":"sum"}).rename(columns={"Quantity": "sum"}).sort_values(by="sum", ascending=False).head(2).reset_index().iloc[1]["Product_ID"]

# %%
df1[df1["Product_ID"] == result1]
