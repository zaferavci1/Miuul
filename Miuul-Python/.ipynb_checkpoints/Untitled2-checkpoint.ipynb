# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby(["sex"]).agg({"survived":"mean"})
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
df.groupby(["sex", "pclass"]).agg({"survived":"mean"})
# Out:
#                survived
# sex    pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
df.groupby(["sex", "pclass"]).agg({"survived":["count", "mean"]})
# Out:
#               survived
#                  count      mean
# sex    pclass
# female 1            94  0.968085
#        2            76  0.921053
#        3           144  0.500000
# male   1           122  0.368852
#        2           108  0.157407
#        3           347  0.135447

# %%
df.fare <30
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: fare, Length: 891, dtype: bool

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
True + False
# Out:
# 1

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.shape[0]
# Out:
# 891

# %%
df.isnull().sum() / df.shape[0]
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df["age"].value_counts() / df.shape[0]
# Out:
# age
# 24.00    0.033670
# 22.00    0.030303
# 18.00    0.029181
# 19.00    0.028058
# 28.00    0.028058
#            ...
# 36.50    0.001122
# 55.50    0.001122
# 0.92     0.001122
# 23.50    0.001122
# 74.00    0.001122
# Name: count, Length: 88, dtype: float64

# %%
df["sex"].value_counts() / df.shape[0]
# Out:
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64

# %%
df["pclass"].value_counts() / df.shape[0]
# Out:
# pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: count, dtype: float64

# %%
kolonlar = ["embark_town","sex", "class", "who"]

# %%
for col in kolonlar:
    print(df[col].value_counts() / df.shape[0])
    print("---------")
# Out:
# embark_town
# Southampton    0.722783
# Cherbourg      0.188552
# Queenstown     0.086420
# Name: count, dtype: float64
# ---------
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64
# ---------
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: count, dtype: float64
# ---------
# who
# man      0.602694
# woman    0.304153
# child    0.093154
# Name: count, dtype: float64
# ---------

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
num_colum = ['survived',  'age', 'sibsp', 'parch', 'fare', 'alone']
cat_colum = ['pclass', 'sex', 'embarked', 'class', 'adult_male', 'who',  'deck', 'embark_town', 'alive',]

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df[num_colum].columns
# Out:
# Index(['survived', 'age', 'sibsp', 'parch', 'fare', 'alone'], dtype='object')

# %%
df_yeni = df[cat_colum]

# %%
df_yeni.head()
# Out:
#    pclass     sex embarked  class  adult_male    who deck  embark_town alive
# 0       3    male        S  Third        True    man  NaN  Southampton    no
# 1       1  female        C  First       False  woman    C    Cherbourg   yes
# 2       3  female        S  Third       False  woman  NaN  Southampton   yes
# 3       1  female        S  First       False  woman    C  Southampton   yes
# 4       3    male        S  Third        True    man  NaN  Southampton    no

# %%
df_yeni
# Out:
#      pclass     sex embarked   class  adult_male    who deck  embark_town  \
# 0         3    male        S   Third        True    man  NaN  Southampton
# 1         1  female        C   First       False  woman    C    Cherbourg
# 2         3  female        S   Third       False  woman  NaN  Southampton
# 3         1  female        S   First       False  woman    C  Southampton
# 4         3    male        S   Third        True    man  NaN  Southampton
# ..      ...     ...      ...     ...         ...    ...  ...          ...
# 886       2    male        S  Second        True    man  NaN  Southampton
# 887       1  female        S   First       False  woman    B  Southampton
# 888       3  female        S   Third       False  woman  NaN  Southampton
# 889       1    male        C   First        True    man    C    Cherbourg
# 890       3    male        Q   Third        True    man  NaN   Queenstown
#
#     alive
# 0      no
# 1     yes
# 2     yes
# 3     yes
# 4      no
# ...

# %%
for col in df_yeni.columns:
    print(df[col].value_counts() / df.shape[0])
    print("---------")
# Out:
# pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: count, dtype: float64
# ---------
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64
# ---------
# embarked
# S    0.722783
# C    0.188552
# Q    0.086420
# Name: count, dtype: float64
# ---------
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: count, dtype: float64
# ---------
# adult_male
# True     0.602694
# False    0.397306
# Name: count, dtype: float64
# ---------
# who
# man      0.602694
# woman    0.304153
# child    0.093154
# Name: count, dtype: float64
# ---------
# deck
# C    0.066218
# B    0.052750
# D    0.037037
# E    0.035915
# A    0.016835
# F    0.014590
# G    0.004489
# Name: count, dtype: float64
# ---------
# embark_town
# Southampton    0.722783
# Cherbourg      0.188552
# Queenstown     0.086420
# Name: count, dtype: float64
# ---------
# alive
# no     0.616162
# yes    0.383838
# Name: count, dtype: float64
# ---------

# %%
def miuul(dataframe):
    for col in dataframe.columns:
        print(df[col].value_counts() / df.shape[0])
        print("---------")

# %%
miuul(df_yeni)
# Out:
# pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: count, dtype: float64
# ---------
# sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64
# ---------
# embarked
# S    0.722783
# C    0.188552
# Q    0.086420
# Name: count, dtype: float64
# ---------
# class
# Third     0.551066
# First     0.242424
# Second    0.206510
# Name: count, dtype: float64
# ---------
# adult_male
# True     0.602694
# False    0.397306
# Name: count, dtype: float64
# ---------
# who
# man      0.602694
# woman    0.304153
# child    0.093154
# Name: count, dtype: float64
# ---------
# deck
# C    0.066218
# B    0.052750
# D    0.037037
# E    0.035915
# A    0.016835
# F    0.014590
# G    0.004489
# Name: count, dtype: float64
# ---------
# embark_town
# Southampton    0.722783
# Cherbourg      0.188552
# Queenstown     0.086420
# Name: count, dtype: float64
# ---------
# alive
# no     0.616162
# yes    0.383838
# Name: count, dtype: float64
# ---------

# %%
df_ = pd.read_csv("Flo_db.csv", delimiter=",")

# %%
df = df_.copy()

# %%
df.head()
# Out:
#      ID                             master_id order_channel  \
# 0     0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App
# 1     1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App
# 2    10  ae608ece-c9d8-11ea-a31e-000d3a38a36f       Ios App
# 3   100  b74c85fa-43a0-11eb-806e-000d3a38a36f   Android App
# 4  1000  04064990-a414-11e9-a2fc-000d3a38a36f   Android App
#
#   last_order_channel first_order_date last_order_date last_order_date_online  \
# 0            Offline       2020-10-30      2021-02-26             2021-02-21
# 1             Mobile       2017-02-08      2021-02-16             2021-02-16
# 2            Offline       2020-07-19      2020-07-25             2020-07-19
# 3            Offline       2020-02-22      2021-03-03             2020-12-21
# 4        Android App       2019-04-12      2020-07-30             2020-07-30
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                            4
# ...

# %%
df.shape
# Out:
# (19945, 15)

# %%
df.tail()
# Out:
#          ID                             master_id order_channel  \
# 19940  9920  ec20447a-0425-11eb-8ffc-000d3a38a36f   Android App
# 19941  9921  6952c4f6-2b99-11ea-853d-000d3a38a36f        Mobile
# 19942  9922  8b1a8eec-e3b9-11ea-b769-000d3a38a36f   Android App
# 19943  9923  a651b628-a7c3-11e9-a2fc-000d3a38a36f        Mobile
# 19944  9924  7f5bee8a-a86d-11e9-a2fc-000d3a38a36f   Android App
#
#       last_order_channel first_order_date last_order_date  \
# 19940            Offline       2020-10-16      2020-11-28
# 19941            Offline       2019-09-14      2021-05-24
# 19942             Mobile       2020-08-21      2021-01-06
# 19943             Mobile       2019-02-27      2020-12-24
# 19944            Offline       2015-06-24      2020-12-18
#
#       last_order_date_online last_order_date_offline  \
# 19940             2020-10-16              2020-11-28
# 19941             2019-11-30              2021-05-24
# 19942             2021-01-06              2020-08-21
# ...

# %%
df.dtypes
# Out:
# ID                                    int64
# master_id                            object
# order_channel                        object
# last_order_channel                   object
# first_order_date                     object
# last_order_date                      object
# last_order_date_online               object
# last_order_date_offline              object
# order_num_total_ever_online           int64
# order_num_total_ever_offline          int64
# customer_value_total_ever_offline    object
# customer_value_total_ever_online     object
# interested_in_categories_12          object
# order_num_total                       int64
# customer_value_total                 object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=19945, step=1)

# %%
df.columns
# Out:
# Index(['ID', 'master_id', 'order_channel', 'last_order_channel',
#        'first_order_date', 'last_order_date', 'last_order_date_online',
#        'last_order_date_offline', 'order_num_total_ever_online',
#        'order_num_total_ever_offline', 'customer_value_total_ever_offline',
#        'customer_value_total_ever_online', 'interested_in_categories_12',
#        'order_num_total', 'customer_value_total'],
#       dtype='object')

# %%
df.values[0]
# Out:
# array([0, 'cc294636-19f0-11eb-8d74-000d3a38a36f', 'Android App',
#        'Offline', '2020-10-30', '2021-02-26', '2021-02-21', '2021-02-26',
#        4, 1, '139,99', '799,38', '[KADIN]', 5, '939,37'], dtype=object)

# %%
df.isnull().sum()
# Out:
# ID                                   0
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# order_num_total                      0
# customer_value_total                 0
# dtype: int64

# %%
secilen_kolonlar = ['ID', 'master_id', 'order_channel', 'last_order_channel', 'order_num_total_ever_online',
       'order_num_total_ever_offline', 'customer_value_total_ever_offline',
       'customer_value_total_ever_online', 'customer_value_total']

# %%
miuul(df[secilen_kolonlar])
# Out:
# ID
# 0        0.00005
# 19909    0.00005
# 19915    0.00005
# 19914    0.00005
# 19913    0.00005
#           ...
# 13063    0.00005
# 13062    0.00005
# 13061    0.00005
# 13060    0.00005
# 9924     0.00005
# Name: count, Length: 19945, dtype: float64
# ---------
# master_id
# cc294636-19f0-11eb-8d74-000d3a38a36f    0.00005
# 3bafb7ee-4cea-11ea-a626-000d3a38a36f    0.00005
# f1f531fe-fe6c-11e9-a5e8-000d3a38a36f    0.00005
# 825e6b00-ab40-11e9-a2fc-000d3a38a36f    0.00005
# 81d0da04-a53e-11e9-a2fc-000d3a38a36f    0.00005
#                                          ...
# f88cf3ea-47f4-11ea-b6c0-000d3a38a36f    0.00005
# a25a9b0e-3cc7-11ea-b550-000d3a38a36f    0.00005
# f18bd732-ac59-11e9-a2fc-000d3a38a36f    0.00005
# 51c16a64-a81c-11e9-a2fc-000d3a38a36f    0.00005
# 7f5bee8a-a86d-11e9-a2fc-000d3a38a36f    0.00005
# Name: count, Length: 19945, dtype: float64
# ---------
# order_channel
# Android App    0.476059
# Mobile         0.244773
# Ios App        0.142041
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# ID
# master_id
# order_channel
# last_order_channel
# first_order_date
# last_order_date
# last_order_date_online
# last_order_date_offline
# order_num_total_ever_online
# order_num_total_ever_offline
# customer_value_total_ever_offline
# customer_value_total_ever_online
# interested_in_categories_12
# order_num_total
# customer_value_total
