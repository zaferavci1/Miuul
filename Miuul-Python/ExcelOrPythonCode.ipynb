# %%
import pandas as pd

# %%
df1 = pd.read_csv("archive/Results1.csv")

# %%
df1.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %%
df2 = df1[~df1.duplicated(subset=['Product_ID', 'Product_Name'], keep='first')]

# %%
df3 =  df2.groupby("Product_Name").agg({"Product_ID":"count"}).sort_values(by="Product_ID", ascending=False).reset_index()

# %%
df3.head(40)
# Out:
#                                          Product_Name  Product_ID
# 0                                             Staples          10
# 1                                     Staple envelope           9
# 2                                   Easy-staple paper           8
# 3                             Staples in misc. colors           7
# 4                                       Staple holder           3
# 5                                      Staple remover           3
# 6                            Prang Drawing Pencil Set           2
# 7                         Eldon Wave Desk Accessories           2
# 8                          KI Adjustable-Height Table           2
# 9       Peel & Seel Recycled Catalog Envelopes, Brown           2
# 10                            Storex Dura Pro Binders           2
# 11                                      Staple magnet           2
# 12                         Staple-based wall hangings           2
# ...

# %%
df3 = df3[df3["Product_ID"]> 1]

# %%
df3.head(10)
# Out:
#                                     Product_Name  Product_ID
# 0                                        Staples          10
# 1                                Staple envelope           9
# 2                              Easy-staple paper           8
# 3                        Staples in misc. colors           7
# 4                                  Staple holder           3
# 5                                 Staple remover           3
# 6                       Prang Drawing Pencil Set           2
# 7                    Eldon Wave Desk Accessories           2
# 8                     KI Adjustable-Height Table           2
# 9  Peel & Seel Recycled Catalog Envelopes, Brown           2

# %%
namelist = []
namelist = df3["Product_Name"]

# %%
df4 = df1[df1["Product_Name"].isin(df3["Product_Name"].values)]

# %%
df4 = df4[~df4.duplicated(subset=['Product_ID', 'Product_Name'], keep='first')]

# %%
df4.to_csv("df4.csv")

# %%
df4 = pd.read_excel("archive/Book1.xlsx", sheet_name="df4")

# %%
df4.head()
# Out:
#                          name               id
# 0     Storex Dura Pro Binders  OFF-BI-10001922
# 1     Staples in misc. colors  OFF-AR-10004707
# 2                     Staples  OFF-FA-10003485
# 3  Staple-based wall hangings  FUR-FU-10004351
# 4              Staple remover  OFF-SU-10000946

# %%
df4["ID"] = df4["id"].str[:4] + "AA" + df4["id"].str[-9:]

# %%
df4.head()
# Out:
#                          name               id               ID
# 0     Storex Dura Pro Binders  OFF-BI-10001922  OFF-AA-10001922
# 1     Staples in misc. colors  OFF-AR-10004707  OFF-AA-10004707
# 2                     Staples  OFF-FA-10003485  OFF-AA-10003485
# 3  Staple-based wall hangings  FUR-FU-10004351  FUR-AA-10004351
# 4              Staple remover  OFF-SU-10000946  OFF-AA-10000946

# %%
for i in range(0, len(df4.index)):
    product_name = df4["name"].iloc[i]
    mask = df1["Product_Name"] == product_name
    if mask.any():
        df1.loc[mask, 'Product_ID'] = df4["id"].iloc[i]

# %%
df1.to_csv("son1.3.csv")

# %%
df1 = pd.read_excel("archive/Book1.xlsx", sheet_name="son1.3")

# %%
df1.head()
# Out:
#    Column1  Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0        0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1        1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
#
#   Customer_ID    Customer_Name    Segment        Country  ... Postal_Code  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...       42420
# 1    CG-12520      Claire Gute   Consumer  United States  ...       42420
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...       90036
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...       33311
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...       33311
#
#   Region       Product_ID         Category Sub_Category  \
# ...

# %%
df2 = df1[~df1.duplicated(subset=['Product_ID', 'Product_Name'], keep='first')]

# %%
df3 =  df2.groupby("Product_ID").agg({"Product_Name":"count"}).sort_values(by="Product_Name", ascending=False).reset_index()

# %%
df3.head()
# Out:
#         Product_ID  Product_Name
# 0  TEC-AC-10003832             2
# 1  OFF-PA-10001970             2
# 2  TEC-PH-10002200             2
# 3  OFF-BI-10002026             2
# 4  OFF-PA-10000477             2

# %%
df3 = df3[df3["Product_Name"]> 1]

# %%
df3.head(50)
# Out:
#          Product_ID  Product_Name
# 0   TEC-AC-10003832             2
# 1   OFF-PA-10001970             2
# 2   TEC-PH-10002200             2
# 3   OFF-BI-10002026             2
# 4   OFF-PA-10000477             2
# 5   OFF-PA-10002195             2
# 6   OFF-BI-10004632             2
# 7   OFF-AR-10001149             2
# 8   OFF-BI-10004654             2
# 9   OFF-PA-10000357             2
# 10  FUR-FU-10004017             2
# 11  OFF-PA-10002377             2
# 12  FUR-FU-10004091             2
# 13  OFF-AP-10000576             2
# 14  FUR-FU-10004270             2
# 15  FUR-FU-10004864             2
# 16  FUR-CH-10001146             2
# 17  FUR-FU-10001473             2
# 18  FUR-FU-10004848             2
# 19  OFF-ST-10001228             2
# 20  TEC-AC-10002550             2
# 21  TEC-PH-10002310             2
# 22  TEC-MA-10001148             2
# 23  TEC-PH-10001795             2
# 24  OFF-PA-10003022             2
# 25  OFF-PA-10000659             2
# ...

# %%
df4 = df1[df1["Product_ID"].isin(df3["Product_ID"])]

# %%
df4.head()
# Out:
#      Column1  Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 29        29      30  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 66        66      67  US-2015-164175 2015-04-30 2015-05-05  Standard Class
# 70        70      71  CA-2016-106075 2016-09-18 2016-09-23  Standard Class
# 128      128     129  US-2016-125969 2016-11-06 2016-11-10    Second Class
# 131      131     132  US-2017-164147 2017-02-02 2017-02-05     First Class
#
#     Customer_ID      Customer_Name      Segment        Country  ...  \
# 29     TB-21520    Tracy Blumstein     Consumer  United States  ...
# 66     PS-18970     Paul Stevenson  Home Office  United States  ...
# 70     HM-14980  Henry MacAllister     Consumer  United States  ...
# 128    LS-16975   Lindsay Shagiari  Home Office  United States  ...
# 131    DW-13585     Dorothy Wardle    Corporate  United States  ...
#
#     Postal_Code   Region       Product_ID         Category Sub_Category  \
# ...

# %%
names = []
names = df4["Product_Name"].drop_duplicates()

# %%
type(names)
# Out:
# pandas.core.series.Series

# %%
names.to_csv("names.csv")

# %%
names = pd.read_excel("archive/Book1.xlsx", sheet_name="names")

# %%
names.head()
# Out:
#   Unnamed: 0                                       Product_Name  \
# 0    Column1        Global Value Mid-Back Manager's Chair, Gray
# 1         29                           Global Task Chair, Black
# 2         66                            DAX Wood Document Frame
# 3         70  Eldon Executive Woodline II Desk Accessories, ...
# 4        128              DMI Eclipse Executive Suite Bookcases
#
#         Porduct_ID
# 0  FUR-AZ-10001146
# 1  FUR-AZ-10001146
# 2  FUR-AZ-10001473
# 3  FUR-AZ-10001473
# 4  FUR-AZ-10002213

# %%
for i in range(0, len(names.index)):
    product_name = names["Product_Name"].iloc[i]
    mask = df1["Product_Name"] == product_name
    if mask.any():
        df1.loc[mask, 'Product_ID'] = names["Porduct_ID"].iloc[i]

# %%
df1.head()
# Out:
#    Column1  Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0        0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1        1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
#
#   Customer_ID    Customer_Name    Segment        Country  ... Postal_Code  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...       42420
# 1    CG-12520      Claire Gute   Consumer  United States  ...       42420
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...       90036
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...       33311
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...       33311
#
#   Region       Product_ID         Category Sub_Category  \
# ...

# %%
df1.to_csv("son1.5.csv")

# %%
df1 = pd.read_excel("archive/Book1.xlsx", sheet_name="son1.5")

# %%
names = pd.read_excel("archive/Book1.xlsx", sheet_name="names")

# %%
names.head()
# Out:
#         Product_ID                                   Product_Name
# 0  TEC-AY-10002550                     Maxell 4.7GB DVD-RW 3/Pack
# 1  TEC-AY-10004531  OtterBox Commuter Series Case - iPhone 5 & 5s
# 2  TEC-AY-10003832             Logitech�P710e Mobile Speakerphone
# 3  TEC-AY-10002200                          Samsung Galaxy Note 2
# 4  TEC-AY-10002310             Panasonic KX T7731-B Digital phone

# %%
for i in range(0, len(names.index)):
    product_name = names["Product_Name"].iloc[i]
    mask = df1["Product_Name"] == product_name
    if mask.any():
        df1.loc[mask, 'Product_ID'] = names["Product_ID"].iloc[i]

# %%
df1.to_csv("son1.6.csv")
