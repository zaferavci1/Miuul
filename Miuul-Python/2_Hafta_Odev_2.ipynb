# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby(["sex"]).agg({"sex":["count"]})
# Out:
#          sex
#        count
# sex
# female   314
# male     577

# %%
df.groupby(["sex"]).agg({"sex":["unique"]})
# Out:
#              sex
#           unique
# sex
# female  [female]
# male      [male]

# %%
df.drop_duplicates().count()
# Out:
# survived       784
# pclass         784
# sex            784
# age            678
# sibsp          784
# parch          784
# fare           784
# embarked       782
# class          784
# who            784
# adult_male     784
# deck           202
# embark_town    782
# alive          784
# alone          784
# dtype: int64

# %%
df.pclass.drop_duplicates()
# Out:
# 0    3
# 1    1
# 9    2
# Name: pclass, dtype: int64

# %%
df[["parch","pclass"]].drop_duplicates().count()
# Out:
# parch     15
# pclass    15
# dtype: int64

# %%
type(df["embarked"])
# Out:
# pandas.core.series.Series

# %%
print(df.embarked.dtype)
# Out:
# object

# %%
df.embarked = df.embarked.astype("category")

# %%
print(df.embarked.dtype)
# Out:
# category

# %%
df["embarked"] == "C"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embarked, Length: 891, dtype: bool

# %%
df[df["embarked"] == "C"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df["embarked"] != "C"
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889    False
# 890     True
# Name: embarked, Length: 891, dtype: bool

# %%
df[df["embarked"] != "S"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
(df["sex"] == "male") & (df["age"] < 30)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890    False
# Length: 891, dtype: bool

# %%
df[(df["sex"] == "male") & (df["age"] < 30)]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# 16          0       3  male   2.0      4      1  29.1250        Q   Third
# 23          1       1  male  28.0      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 877         0       3  male  19.0      0      0   7.8958        S   Third
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Görev 10: Fare'i 500'den büyük veya yaşı 70 den büyük yolcuların bilgilerini gösteriniz.
(df["fare"] > 500) & (df["age"] > 70)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df[(df["fare"] > 500) | (df["age"] > 70)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 851         0       3    male  74.0      0      0    7.7750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# ...

# %%
# Görev 11: Her bir değişkendeki boş değerlerin toplamını bulunuz.
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Görev 12: who değişkenini dataframe'den düşürün.
pd.DataFrame(df["who"])
# Out:
#        who
# 0      man
# 1    woman
# 2    woman
# 3    woman
# 4      man
# ..     ...
# 886    man
# 887  woman
# 888  woman
# 889    man
# 890    man
#
# [891 rows x 1 columns]

# %%
df.drop("who", axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
# Görev 13: deck değişkenindeki boş değerleri deck değişkenin en çok tekrar eden değeri (mode) ile doldurunuz
df["deck"].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: deck, Length: 891, dtype: bool

# %%
df[df["deck"].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
deck_mode = df["deck"].mode()
deck_mode
# Out:
# 0    C
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
type(deck_mode)
# Out:
# pandas.core.series.Series

# %%
type(deck_mode[0])
# Out:
# str

# %%
deck_mode[0]
# Out:
# 'C'

# %%
df.deck.fillna(deck_mode[0], inplace=True)
# Out:
# /var/folders/st/g578wh254q58gyrbtjhdkz380000gn/T/ipykernel_28765/3637036065.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.deck.fillna(deck_mode[0], inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Görev 14: age değikenindeki boş değerleri age değişkenin medyanı ile doldurun.
df["age"].fillna(df.age.median(), inplace=True)
# Out:
# /var/folders/st/g578wh254q58gyrbtjhdkz380000gn/T/ipykernel_28765/1705676249.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df.age.median(), inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Görev 15: survived değişkeninin Pclass ve Cinsiyet değişkenleri kırılımınında sum, count, mean değerlerini bulunuz.
df.groupby(["pclass","sex"]).agg({"survived":["sum","count","mean"]})
# Out:
#               survived
#                    sum count      mean
# pclass sex
# 1      female       91    94  0.968085
#        male         45   122  0.368852
# 2      female       70    76  0.921053
#        male         17   108  0.157407
# 3      female       72   144  0.500000
#        male         47   347  0.135447

# %%
# Görev 16: 30 yaşın altında olanlar 1, 30'a eşit ve üstünde olanlara 0 vericek bir fonksiyon yazınız.
df["age_flag"] = [1 if degisken < 30 else 0 for degisken in df["age"]]
df["age_flag2"] = df["age"].apply(lambda x: 1 if x<30 else 0)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# Görev 17: Seaborn kütüphanesi içerisinden Tips veri setini tanımlayınız.
df2 = sns.load_dataset("tips")

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Görev 18: Time değişkeninin kategorilerine (Dinner, Lunch) göre total_bill   değerlerinin toplamını, min, max ve ortalamasını bulunuz.
df2.groupby("time").agg({"total_bill":["sum","min","max","mean"]})
# Out:
# /var/folders/st/g578wh254q58gyrbtjhdkz380000gn/T/ipykernel_28765/2706230253.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2.groupby("time").agg({"total_bill":["sum","min","max","mean"]})
#        total_bill
#               sum   min    max       mean
# time
# Lunch     1167.47  7.51  43.11  17.168676
# Dinner    3660.30  3.07  50.81  20.797159

# %%
# Görev 19: Günlere ve time göre total_bill değerlerinin toplamını, min, max ve ortalamasını bulunuz.
df2.groupby(["day","time"]).agg({"total_bill":["sum","min","max","mean"]})
# Out:
# /var/folders/st/g578wh254q58gyrbtjhdkz380000gn/T/ipykernel_28765/3548223300.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2.groupby(["day","time"]).agg({"total_bill":["sum","min","max","mean"]})
#             total_bill
#                    sum    min    max       mean
# day  time
# Thur Lunch     1077.55   7.51  43.11  17.664754
#      Dinner      18.78  18.78  18.78  18.780000
# Fri  Lunch       89.92   8.58  16.27  12.845714
#      Dinner     235.96   5.75  40.17  19.663333
# Sat  Lunch        0.00    NaN    NaN        NaN
#      Dinner    1778.40   3.07  50.81  20.441379
# Sun  Lunch        0.00    NaN    NaN        NaN
#      Dinner    1627.16   7.25  48.17  21.410000

# %%
# Görev 20:Lunch zamanına ve kadın müşterilere ait total_bill ve tip değerlerinin day'e göre toplamını, min, max ve ortalamasını bulunuz
df2[(df2["time"] == "Lunch") & (df2["sex"] == "Female")].groupby(["day"]).agg({"total_bill":["sum","min","max","mean"],"tip":["sum","min","max","mean"]})
# Out:
# /var/folders/st/g578wh254q58gyrbtjhdkz380000gn/T/ipykernel_28765/1333217397.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2[(df2["time"] == "Lunch") & (df2["sex"] == "Female")].groupby(["day"]).agg({"total_bill":["sum","min","max","mean"],"tip":["sum","min","max","mean"]})
#      total_bill                            tip
#             sum    min    max      mean    sum   min   max      mean
# day
# Thur     516.11   8.35  43.11  16.64871  79.42  1.25  5.17  2.561935
# Fri       55.76  10.09  16.27  13.94000  10.98  2.00  3.48  2.745000
# Sat        0.00    NaN    NaN       NaN   0.00   NaN   NaN       NaN
# Sun        0.00    NaN    NaN       NaN   0.00   NaN   NaN       NaN

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Görev 21: size'i 3'ten küçük, total_bill'i 10'dan büyük olan siparişlerin ortalaması nedir?
df2[(df2["size"] < 3 ) & (df2["total_bill"] > 10)][["total_bill","tip","size"]].agg(["mean"])
# Out:
#       total_bill       tip      size
# mean   17.184965  2.638811  1.993007

# %%
# Görev 22: total_bill_tip_sum adında yeni bir değişken oluşturun.   Her bir müşterinin ödediği totalbill ve tip in toplamını versin.
df2["total_bill_tip_sum"] = (df2["total_bill"] + df2["tip"])

# %%
# Görev 23: Total_bill değişkeninin kadın ve erkek için ayrı ayrı ortalamasını bulun. Bulduğunuz ortalamaların 
#altında olanlara 0, üstünde ve eşit olanlara bir verildiği yeni bir total_bill_flag değişkeni oluşturun.
#Dikkat !! Female olanlar için kadınlar için bulunan ortalama dikkate alıncak, male için ise erkekler için bulunan ortalama dikkate alınacak. 
#Parametre olarak cinsiyet ve total_bill alan bir fonksiyon yazarak başlayın. (If-else koşulları içerecek)
df2_groupBy = df2.groupby("sex").agg({"total_bill":"mean"}).reset_index()
# Out:
# /var/folders/st/g578wh254q58gyrbtjhdkz380000gn/T/ipykernel_28765/541147947.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2_groupBy = df2.groupby("sex").agg({"total_bill":"mean"}).reset_index()

# %%
df2_groupBy
# Out:
#       sex  total_bill
# 0    Male   20.744076
# 1  Female   18.056897

# %%
df2_male_mean = df2_groupBy.iloc[0,1]

# %%
df2_male_mean
# Out:
# 20.74407643312102

# %%
df2_male_female = df2_groupBy.iloc[1,1]

# %%
df2_male_female
# Out:
# 18.05689655172414

# %%
def ortalama_kontrol(cinsiyet, fatura):
    if cinsiyet == "Female":
         if fatura >= df2_male_female:
             return 1
         else:
             return 0
    else:
        if fatura >= df2_male_mean:
            return 1
        else:
            return 0

# %%
df2["total_bill_flag"] = df2.apply(lambda x: ortalama_kontrol(x["sex"], x["total_bill"]), axis=1)

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip_sum  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2               18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3               12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3               24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2               26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4               28.20
# ..          ...   ...     ...    ...   ...     ...   ...                 ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3               34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2               29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2               24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2               19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2               21.78
#
#      total_bill_flag
# 0                  0
# ...

# %%
# Görev 24: total_bill_flag değişkenini kullanarak cinsiyetlere göre ortalamanın altında ve üstünde olanların sayısını gözlemleyin.
df2.groupby(["total_bill_flag", "sex"]).agg({"sex":"count"})
# Out:
# /var/folders/st/g578wh254q58gyrbtjhdkz380000gn/T/ipykernel_28765/2499032077.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2.groupby(["total_bill_flag", "sex"]).agg({"sex":"count"})
#                         sex
# total_bill_flag sex
# 0               Male     95
#                 Female   54
# 1               Male     62
#                 Female   33

# %%
# Görev 25: total_bill_tip_sum değişkenine göre büyükten küçüğe sıralayınız ve ilk 30 kişiyi yeni bir dataframe'e atayınız.ÖDEV 2
df2_1 = df2["total_bill_tip_sum"].sort_values().head(30)

# %%
df2_1
# Out:
# 67      4.07
# 92      6.75
# 111     8.25
# 195     9.00
# 218     9.18
# 149     9.51
# 135     9.76
# 145     9.85
# 126    10.00
# 222    10.50
# 6      10.77
# 30     11.00
# 43     11.00
# 235    11.32
# 53     11.50
# 148    11.51
# 75     11.76
# 82     11.90
# 10     11.98
# 1      12.00
# 16     12.00
# 226    12.09
# 117    12.15
# 168    12.20
# 233    12.24
# 136    12.33
# 196    12.34
# 172    12.40
# 169    12.63
# 132    12.67
# Name: total_bill_tip_sum, dtype: float64

# %%
pd.set_option('display.max_rows', 100)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...
